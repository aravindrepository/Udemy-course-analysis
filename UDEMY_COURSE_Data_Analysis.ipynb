# %% [markdown]
# <a href="https://colab.research.google.com/github/aravindrepository/Udemy-course-analysis/blob/main/UDEMY_COURSE_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig=plt.figure()

# %%
df=pd.read_csv('file.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.tail(n=3)
# Out:
#       course_id                                       course_title  is_paid  \
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures       level  \
# 3679    40              723          130            37  All Levels
# 3680  Free              229            0            33  All Levels
# 3681    50               12            1            15  All Levels
#
#      content_duration   published_timestamp           subject
# 3679        6.5 hours  2015-11-11T18:55:45Z   Web Development
# 3680          2 hours  2017-05-26T16:45:55Z  Business Finance
# 3681        1.5 hours  2016-09-26T22:19:48Z    Graphic Design

# %% [markdown]
# COLUMNS

# %%
df.shape
# Out:
# (3682, 11)

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.course_title.unique()
# Out:
# array(['#1 Piano Hand Coordination: Play 10th Ballad in Eb Key songs',
#        '#10 Hand Coordination - Transfer Chord Ballad 9 - C & Bb Key',
#        '#12 Hand Coordination: Let your Hands dance with Ballad 9', ...,
#        'Zend Framework 2: Learn the PHP framework ZF2 from scratch',
#        "Zoho Books Gestion Financière d'Entreprise pas à pas",
#        'Zombie Apocalypse Photoshop Actions'], dtype=object)

# %%
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# ### Max course and min course

# %%
df.subject.max()
# Out:
# 'Web Development'

# %%
df.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
df.subject.value_counts().plot(kind='bar')
plt.title('Max no of course')
plt.xlabel('Subject')
plt.ylabel('No.of Courses')
# Out:
# Text(0, 0.5, 'No.of Courses')

# %% [markdown]
# ###Is Course Paid or Not

# %%
isPaid=df.is_paid==False

# %%
df[isPaid].head()
# Out:
#     course_id                                       course_title  is_paid  \
# 41     286070        5 lecciones que todo guitarrista debe tomar    False
# 49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57     955914  A beginner`s guide to fingerpicking and strumm...    False
# 67     270976                             A how to guide in HTML    False
# 74    1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
#
#    price  num_subscribers  num_reviews  num_lectures           level  \
# 41  Free             4452          263            14  Beginner Level
# 49  Free             4529          193             7  Beginner Level
# 57  Free             3481           29            20  Beginner Level
# 67  Free             7318          205             8  Beginner Level
# 74  Free              338            7             6  Beginner Level
#
#    content_duration   published_timestamp              subject
# ...

# %% [markdown]
# ###Paid courses

# %%
df[df.is_paid==True].head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# ### Top selling Course and lowest selling Course

# %% [markdown]
# ###Top selling Courses

# %%
df.num_subscribers.max()
# Out:
# 268923

# %%
df.sort_values('num_subscribers',ascending=False).head()
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 2230  Free           268923         8629            45      All Levels
# 776   Free           161029          279            27  Beginner Level
# 3385   200           121584        27445           342      All Levels
# 640   Free           120291         5924            30  Beginner Level
# 3316   200           114512        22412           304      All Levels
#
#      content_duration   published_timestamp          subject
# ...

# %% [markdown]
# ##lowest selling courses

# %%
df.sort_values('num_subscribers').head(n=10)
# Out:
#       course_id                                       course_title  is_paid  \
# 649     1233314                      Building a Balanced Scorecard     True
# 3259    1232282          The Cash Flow Statement - An Introduction     True
# 3261    1275872                    The Complete Adobe Spark Course     True
# 910      726314       Create Beautiful Image Maps for Your Website     True
# 3328     715476        The Cuckoo Strategy to get European Funding     True
# 1325    1187084  Forex how traders beat the markest with little...     True
# 2596     185526                             MicroStation - Células     True
# 2597     185526                             MicroStation - Células     True
# 848     1232390                                   Corporate Ethics     True
# 2900     995384  Professional Business Logo Design Using Free O...     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %% [markdown]
# ###Courses where no.of subscribers are greater than 0 and lesser than 500

# %%
df[(df.num_subscribers > 0 ) & (df.num_subscribers < 500)]
# Out:
#       course_id                                       course_title  is_paid  \
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# ...         ...                                                ...      ...
# 3669     180384                               Yield Curve Dynamics     True
# 3672    1031698                        You Can Play Jazz Saxophone     True
# 3673      79364                       Your Business by the Numbers     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# ###All web development Courses and its top reviews

# %%
df[df['subject']=='Web Development']
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3670     560996  You can create Incredible Websites with HTML C...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# ###Web Development Courses

# %%
df[df['subject']=='Web Development'].head()
# Out:
#     course_id                                       course_title  is_paid  \
# 11      64605                                         1 Hour CSS     True
# 12      64422                                        1 Hour HTML     True
# 13      63612                                  1 Hour JavaScript     True
# 14      72262                                      1 hour jQuery     True
# 24     975916  17 Complete JavaScript   projects explained st...     True
#
#    price  num_subscribers  num_reviews  num_lectures           level  \
# 11   100            18324          333            16  Beginner Level
# 12   200            16212          514            20  Beginner Level
# 13   200            22999          602            18  Beginner Level
# 14   100             5456          133            25  Beginner Level
# 24   185              327           26           106  Beginner Level
#
#    content_duration   published_timestamp          subject
# ...

# %% [markdown]
# ### Free Web Developement Courses

# %%
df[(df.subject=='Web Development') & (df.is_paid==False) ]
# Out:
#       course_id                                       course_title  is_paid  \
# 67       270976                             A how to guide in HTML    False
# 280     1121650                  Angular 2 Routing: Up And Running    False
# 293     1102962                      Angular Material - Quickstart    False
# 296     1127988                     Angular Tutorial For Beginners    False
# 298      808622  AngularJS Authentication: Secure Your App with...    False
# ...         ...                                                ...      ...
# 3600     226534          WordPress Backup And Restore Fundamentals    False
# 3602     883706  Wordpress Beginner Tutorial: Build Your First ...    False
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
#
# ...

# %% [markdown]
# ###Paid Web Development Courses

# %%
a=df[(df.subject=='Web Development')&(df.is_paid==True)]
a
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3670     560996  You can create Incredible Websites with HTML C...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
a.count()
# Out:
# course_id              1067
# course_title           1067
# is_paid                1067
# price                  1067
# num_subscribers        1067
# num_reviews            1067
# num_lectures           1067
# level                  1067
# content_duration       1067
# published_timestamp    1067
# subject                1067
# dtype: int64

# %% [markdown]
# ###Courses contains "Java Script"

# %%
df[df.course_title.str.contains('JavaScript')]
# Out:
#       course_id                                       course_title  is_paid  \
# 13        63612                                  1 Hour JavaScript     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# 61       221920  A Beginner's Guide to the Meteor JavaScript Fr...     True
# 95       886614                Accelerated ES6 JavaScript Training     True
# 96       886300                    Accelerated JavaScript Training     True
# ...         ...                                                ...      ...
# 3296    1270392  The Complete JavaScript, HTML and CSS Tutorial...     True
# 3503     895096                        Ultimate JavaScript Objects     True
# 3504     909836                        Ultimate JavaScript Strings    False
# 3524     711592                      Using Modern JavaScript Today     True
# 3546     900434  VueJS V1 Introduction to VueJS JavaScript Fram...     True
#
# ...

# %% [markdown]
# ###Courses Containing "Python"

# %%
df[df.course_title.str.contains('Python')].head(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df[df.course_title.str.contains('Python')].shape
# Out:
# (29, 11)

# %% [markdown]
# ###Courses Published in 2016

# %%
df['published_timestamp']
# Out:
# 0       2014-09-18T05:07:05Z
# 1       2017-04-12T19:06:34Z
# 2       2017-04-26T18:34:57Z
# 3       2017-02-21T23:48:18Z
# 4       2017-02-21T23:44:49Z
#                 ...
# 3677    2015-04-20T22:15:17Z
# 3678    2015-10-26T20:04:21Z
# 3679    2015-11-11T18:55:45Z
# 3680    2017-05-26T16:45:55Z
# 3681    2016-09-26T22:19:48Z
# Name: published_timestamp, Length: 3682, dtype: object

# %%
df['published_timestamp']=pd.to_datetime(df.published_timestamp)
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
#converter and added to year
df['Year']=df['published_timestamp'].dt.year
df[df['Year']==2016]
# Out:
#       course_id                                       course_title  is_paid  \
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 9        738910  [Value Investing] Where White People Keep Thei...     True
# 18       897162                101 Awesome Rockabilly Guitar Licks     True
# 22       759972                150 Rock Guitar Licks You MUST Know     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3664     968292                        XPATH :basics for beginners     True
# 3665     968304                       XQUERY :basics for beginners     True
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
df[df['Year']==2016].count()
# Out:
# course_id              1206
# course_title           1206
# is_paid                1206
# price                  1206
# num_subscribers        1206
# num_reviews            1206
# num_lectures           1206
# level                  1206
# content_duration       1206
# published_timestamp    1206
# subject                1206
# Year                   1206
# dtype: int64

# %% [markdown]
# ###Max and Min no.of Subs in each Courses

# %%
df.groupby('subject')['num_subscribers'].count()
# Out:
# subject
# Business Finance       1199
# Graphic Design          603
# Musical Instruments     680
# Web Development        1200
# Name: num_subscribers, dtype: int64

# %%
df.groupby('subject')['num_subscribers'].min()
# Out:
# subject
# Business Finance        0
# Graphic Design          0
# Musical Instruments     0
# Web Development        19
# Name: num_subscribers, dtype: int64

# %%
df.groupby('subject')['num_subscribers'].max()
# Out:
# subject
# Business Finance        65576
# Graphic Design          53851
# Musical Instruments    101154
# Web Development        268923
# Name: num_subscribers, dtype: int64
